# %%
import pandas as pd
import pymongo
from psycopg2 import sql
import psycopg2

# %%
renewable_client = pymongo.MongoClient("mongodb://localhost:27017/")

# %%
renewable_db = renewable_client["co2_renew_life_db"]

# %%
print(renewable_db)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'co2_renew_life_db')

# %%
renewable_collection = renewable_db["renewable_energy"]

# %%
renewable_all_records = renewable_collection.find()

# %%
print(renewable_all_records)
# Out:
# <pymongo.synchronous.cursor.Cursor object at 0x000002A87B03B790>

# %%
renewable_all_records = renewable_collection.find()

# %%
print(renewable_all_records)
# Out:
# <pymongo.synchronous.cursor.Cursor object at 0x000002A87B040FD0>

# %%
renewable_list_cursor=list(renewable_all_records)

# %%
renewable_list_cursor
# Out:
# [{'_id': ObjectId('6808a04ef7b9659dcdf08882'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1965,
#   'Renewables (% equivalent primary energy)': 5.7402806},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08883'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1966,
#   'Renewables (% equivalent primary energy)': 6.1139693},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08884'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1967,
#   'Renewables (% equivalent primary energy)': 6.31658},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08885'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1968,
#   'Renewables (% equivalent primary energy)': 6.994845},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08886'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1969,
#   'Renewables (% equivalent primary energy)': 7.9439163},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08887'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1970,
#   'Renewables (% equivalent primary energy)': 9.148895},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08888'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1971,
#   'Renewables (% equivalent primary energy)': 8.124994},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08889'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1972,
#   'Renewables (% equivalent primary energy)': 8.747272},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0888a'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1973,
#   'Renewables (% equivalent primary energy)': 8.54162},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0888b'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1974,
#   'Renewables (% equivalent primary energy)': 9.252387},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0888c'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1975,
#   'Renewables (% equivalent primary energy)': 9.228769},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0888d'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1976,
#   'Renewables (% equivalent primary energy)': 9.41638},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0888e'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1977,
#   'Renewables (% equivalent primary energy)': 9.803094},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0888f'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1978,
#   'Renewables (% equivalent primary energy)': 9.518462},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08890'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1979,
#   'Renewables (% equivalent primary energy)': 9.349527},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08891'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1980,
#   'Renewables (% equivalent primary energy)': 8.481442},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08892'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1981,
#   'Renewables (% equivalent primary energy)': 7.8527517},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08893'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1982,
#   'Renewables (% equivalent primary energy)': 7.3734274},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08894'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1983,
#   'Renewables (% equivalent primary energy)': 6.456112},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08895'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1984,
#   'Renewables (% equivalent primary energy)': 6.1585774},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08896'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1985,
#   'Renewables (% equivalent primary energy)': 6.5793424},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08897'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1986,
#   'Renewables (% equivalent primary energy)': 6.7159667},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08898'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1987,
#   'Renewables (% equivalent primary energy)': 6.243963},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08899'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1988,
#   'Renewables (% equivalent primary energy)': 6.3621163},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0889a'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1989,
#   'Renewables (% equivalent primary energy)': 6.66546},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0889b'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1990,
#   'Renewables (% equivalent primary energy)': 6.5857716},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0889c'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1991,
#   'Renewables (% equivalent primary energy)': 6.9810143},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0889d'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1992,
#   'Renewables (% equivalent primary energy)': 6.5694675},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0889e'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1993,
#   'Renewables (% equivalent primary energy)': 6.43179},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0889f'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1994,
#   'Renewables (% equivalent primary energy)': 6.3092456},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088a0'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1995,
#   'Renewables (% equivalent primary energy)': 6.306244},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088a1'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1996,
#   'Renewables (% equivalent primary energy)': 6.4332542},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088a2'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1997,
#   'Renewables (% equivalent primary energy)': 6.465725},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088a3'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1998,
#   'Renewables (% equivalent primary energy)': 6.676159},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088a4'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1999,
#   'Renewables (% equivalent primary energy)': 6.858631},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088a5'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2000,
#   'Renewables (% equivalent primary energy)': 7.2029395},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088a6'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2001,
#   'Renewables (% equivalent primary energy)': 7.4362373},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088a7'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2002,
#   'Renewables (% equivalent primary energy)': 7.671944},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088a8'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2003,
#   'Renewables (% equivalent primary energy)': 7.105203},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088a9'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2004,
#   'Renewables (% equivalent primary energy)': 6.980063},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088aa'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2005,
#   'Renewables (% equivalent primary energy)': 7.0285006},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088ab'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2006,
#   'Renewables (% equivalent primary energy)': 7.1611776},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088ac'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2007,
#   'Renewables (% equivalent primary energy)': 7.0572457},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088ad'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2008,
#   'Renewables (% equivalent primary energy)': 6.761787},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088ae'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2009,
#   'Renewables (% equivalent primary energy)': 6.810709},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088af'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2010,
#   'Renewables (% equivalent primary energy)': 7.1290402},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088b0'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2011,
#   'Renewables (% equivalent primary energy)': 7.2594023},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088b1'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2012,
#   'Renewables (% equivalent primary energy)': 6.9972486},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088b2'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2013,
#   'Renewables (% equivalent primary energy)': 7.189637},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088b3'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2014,
#   'Renewables (% equivalent primary energy)': 7.5156765},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088b4'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2015,
#   'Renewables (% equivalent primary energy)': 7.527505},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088b5'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2016,
#   'Renewables (% equivalent primary energy)': 7.404274},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088b6'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2017,
#   'Renewables (% equivalent primary energy)': 7.6419463},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088b7'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2018,
#   'Renewables (% equivalent primary energy)': 8.005552},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088b8'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2019,
#   'Renewables (% equivalent primary energy)': 8.356321},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088b9'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2020,
#   'Renewables (% equivalent primary energy)': 9.415897},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088ba'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2021,
#   'Renewables (% equivalent primary energy)': 9.152215},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088bb'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2022,
#   'Renewables (% equivalent primary energy)': 9.298186},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088bc'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2023,
#   'Renewables (% equivalent primary energy)': 9.826173},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088bd'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1965,
#   'Renewables (% equivalent primary energy)': 5.7402806},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088be'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1966,
#   'Renewables (% equivalent primary energy)': 6.113969},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088bf'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1967,
#   'Renewables (% equivalent primary energy)': 6.31658},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088c0'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1968,
#   'Renewables (% equivalent primary energy)': 6.994845},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088c1'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1969,
#   'Renewables (% equivalent primary energy)': 7.9439154},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088c2'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1970,
#   'Renewables (% equivalent primary energy)': 9.148896},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088c3'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1971,
#   'Renewables (% equivalent primary energy)': 8.124996},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088c4'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1972,
#   'Renewables (% equivalent primary energy)': 8.7472725},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088c5'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1973,
#   'Renewables (% equivalent primary energy)': 8.54162},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088c6'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1974,
#   'Renewables (% equivalent primary energy)': 9.252388},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088c7'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1975,
#   'Renewables (% equivalent primary energy)': 9.228768},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088c8'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1976,
#   'Renewables (% equivalent primary energy)': 9.416379},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088c9'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1977,
#   'Renewables (% equivalent primary energy)': 9.803097},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088ca'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1978,
#   'Renewables (% equivalent primary energy)': 9.518462},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088cb'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1979,
#   'Renewables (% equivalent primary energy)': 9.349527},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088cc'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1980,
#   'Renewables (% equivalent primary energy)': 8.481442},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088cd'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1981,
#   'Renewables (% equivalent primary energy)': 7.8527517},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088ce'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1982,
#   'Renewables (% equivalent primary energy)': 7.3734274},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088cf'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1983,
#   'Renewables (% equivalent primary energy)': 6.456112},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088d0'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1984,
#   'Renewables (% equivalent primary energy)': 6.1585774},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088d1'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1985,
#   'Renewables (% equivalent primary energy)': 6.5793424},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088d2'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1986,
#   'Renewables (% equivalent primary energy)': 6.7159667},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088d3'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1987,
#   'Renewables (% equivalent primary energy)': 6.243963},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088d4'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1988,
#   'Renewables (% equivalent primary energy)': 6.3621163},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088d5'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1989,
#   'Renewables (% equivalent primary energy)': 6.6654606},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088d6'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1990,
#   'Renewables (% equivalent primary energy)': 6.5857716},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088d7'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1991,
#   'Renewables (% equivalent primary energy)': 6.9810143},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088d8'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1992,
#   'Renewables (% equivalent primary energy)': 6.5694675},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088d9'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1993,
#   'Renewables (% equivalent primary energy)': 6.43179},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088da'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1994,
#   'Renewables (% equivalent primary energy)': 6.3092456},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088db'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1995,
#   'Renewables (% equivalent primary energy)': 6.306244},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088dc'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1996,
#   'Renewables (% equivalent primary energy)': 6.433255},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088dd'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1997,
#   'Renewables (% equivalent primary energy)': 6.465725},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088de'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1998,
#   'Renewables (% equivalent primary energy)': 6.6761603},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088df'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1999,
#   'Renewables (% equivalent primary energy)': 6.8586307},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088e0'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2000,
#   'Renewables (% equivalent primary energy)': 7.2029395},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088e1'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2001,
#   'Renewables (% equivalent primary energy)': 7.436237},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088e2'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2002,
#   'Renewables (% equivalent primary energy)': 7.671944},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088e3'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2003,
#   'Renewables (% equivalent primary energy)': 7.105202},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088e4'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2004,
#   'Renewables (% equivalent primary energy)': 6.980063},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088e5'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2005,
#   'Renewables (% equivalent primary energy)': 7.0285006},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088e6'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2006,
#   'Renewables (% equivalent primary energy)': 7.161177},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088e7'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2007,
#   'Renewables (% equivalent primary energy)': 7.0572457},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088e8'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2008,
#   'Renewables (% equivalent primary energy)': 6.761787},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088e9'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2009,
#   'Renewables (% equivalent primary energy)': 6.8107085},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088ea'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2010,
#   'Renewables (% equivalent primary energy)': 7.12904},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088eb'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2011,
#   'Renewables (% equivalent primary energy)': 7.2594023},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088ec'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2012,
#   'Renewables (% equivalent primary energy)': 6.9972486},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088ed'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2013,
#   'Renewables (% equivalent primary energy)': 7.189637},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088ee'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2014,
#   'Renewables (% equivalent primary energy)': 7.5156765},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088ef'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2015,
#   'Renewables (% equivalent primary energy)': 7.527505},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088f0'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2016,
#   'Renewables (% equivalent primary energy)': 7.404273},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088f1'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2017,
#   'Renewables (% equivalent primary energy)': 7.6419473},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088f2'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2018,
#   'Renewables (% equivalent primary energy)': 8.005553},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088f3'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2019,
#   'Renewables (% equivalent primary energy)': 8.356321},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088f4'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2020,
#   'Renewables (% equivalent primary energy)': 9.415897},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088f5'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2021,
#   'Renewables (% equivalent primary energy)': 9.152214},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088f6'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2022,
#   'Renewables (% equivalent primary energy)': 9.298185},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088f7'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2023,
#   'Renewables (% equivalent primary energy)': 9.826172},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088f8'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1965,
#   'Renewables (% equivalent primary energy)': 4.7630677},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088f9'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1966,
#   'Renewables (% equivalent primary energy)': 3.518747},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088fa'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1967,
#   'Renewables (% equivalent primary energy)': 4.291954},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088fb'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1968,
#   'Renewables (% equivalent primary energy)': 5.4861946},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088fc'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1969,
#   'Renewables (% equivalent primary energy)': 3.1827633},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088fd'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1970,
#   'Renewables (% equivalent primary energy)': 4.6656837},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088fe'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1971,
#   'Renewables (% equivalent primary energy)': 2.4559188},
#  {'_id': ObjectId('6808a04ef7b9659dcdf088ff'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1972,
#   'Renewables (% equivalent primary energy)': 3.278343},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08900'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1973,
#   'Renewables (% equivalent primary energy)': 4.175826},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08901'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1974,
#   'Renewables (% equivalent primary energy)': 2.494738},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08902'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1975,
#   'Renewables (% equivalent primary energy)': 1.3782818},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08903'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1976,
#   'Renewables (% equivalent primary energy)': 1.4010222},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08904'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1977,
#   'Renewables (% equivalent primary energy)': 0.8817282},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08905'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1978,
#   'Renewables (% equivalent primary energy)': 0.6521151},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08906'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1979,
#   'Renewables (% equivalent primary energy)': 0.5792936},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08907'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1980,
#   'Renewables (% equivalent primary energy)': 0.4290016},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08908'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1981,
#   'Renewables (% equivalent primary energy)': 0.50294036},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08909'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1982,
#   'Renewables (% equivalent primary energy)': 0.5708701},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0890a'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1983,
#   'Renewables (% equivalent primary energy)': 0.25644946},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0890b'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1984,
#   'Renewables (% equivalent primary energy)': 0.5136736},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0890c'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1985,
#   'Renewables (% equivalent primary energy)': 0.72826535},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0890d'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1986,
#   'Renewables (% equivalent primary energy)': 0.2664045},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0890e'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1987,
#   'Renewables (% equivalent primary energy)': 0.5174274},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0890f'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1988,
#   'Renewables (% equivalent primary energy)': 0.17717436},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08910'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1989,
#   'Renewables (% equivalent primary energy)': 0.2249582},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08911'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1990,
#   'Renewables (% equivalent primary energy)': 0.1267387},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08912'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1991,
#   'Renewables (% equivalent primary energy)': 0.277607},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08913'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1992,
#   'Renewables (% equivalent primary energy)': 0.18375748},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08914'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1993,
#   'Renewables (% equivalent primary energy)': 0.35028014},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08915'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1994,
#   'Renewables (% equivalent primary energy)': 0.16257899},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08916'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1995,
#   'Renewables (% equivalent primary energy)': 0.18224756},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08917'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1996,
#   'Renewables (% equivalent primary energy)': 0.1288034},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08918'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1997,
#   'Renewables (% equivalent primary energy)': 0.074455895},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08919'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1998,
#   'Renewables (% equivalent primary energy)': 0.20617963},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0891a'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1999,
#   'Renewables (% equivalent primary energy)': 0.1927434},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0891b'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2000,
#   'Renewables (% equivalent primary energy)': 0.053235486},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0891c'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2001,
#   'Renewables (% equivalent primary energy)': 0.065218486},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0891d'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2002,
#   'Renewables (% equivalent primary energy)': 0.05167676},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0891e'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2003,
#   'Renewables (% equivalent primary energy)': 0.228104},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0891f'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2004,
#   'Renewables (% equivalent primary energy)': 0.2067869},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08920'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2005,
#   'Renewables (% equivalent primary energy)': 0.43411884},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08921'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2006,
#   'Renewables (% equivalent primary energy)': 0.16327195},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08922'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2007,
#   'Renewables (% equivalent primary energy)': 0.15990457},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08923'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2008,
#   'Renewables (% equivalent primary energy)': 0.1877543},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08924'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2009,
#   'Renewables (% equivalent primary energy)': 0.21278548},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08925'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2010,
#   'Renewables (% equivalent primary energy)': 0.11513415},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08926'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2011,
#   'Renewables (% equivalent primary energy)': 0.23525994},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08927'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2012,
#   'Renewables (% equivalent primary energy)': 0.22453195},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08928'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2013,
#   'Renewables (% equivalent primary energy)': 0.06476319},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08929'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2014,
#   'Renewables (% equivalent primary energy)': 0.11750259},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0892a'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2015,
#   'Renewables (% equivalent primary energy)': 0.09681336},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0892b'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2016,
#   'Renewables (% equivalent primary energy)': 0.14580713},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0892c'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2017,
#   'Renewables (% equivalent primary energy)': 0.24701828},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0892d'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2018,
#   'Renewables (% equivalent primary energy)': 0.28842947},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0892e'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2019,
#   'Renewables (% equivalent primary energy)': 0.29497427},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0892f'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2020,
#   'Renewables (% equivalent primary energy)': 0.30043116},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08930'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2021,
#   'Renewables (% equivalent primary energy)': 0.25285673},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08931'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2022,
#   'Renewables (% equivalent primary energy)': 0.24182516},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08932'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2023,
#   'Renewables (% equivalent primary energy)': 0.27036947},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08933'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1965,
#   'Renewables (% equivalent primary energy)': 1.1026944},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08934'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1966,
#   'Renewables (% equivalent primary energy)': 1.0818663},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08935'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1967,
#   'Renewables (% equivalent primary energy)': 1.0765308},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08936'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1968,
#   'Renewables (% equivalent primary energy)': 1.2272897},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08937'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1969,
#   'Renewables (% equivalent primary energy)': 1.0651326},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08938'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1970,
#   'Renewables (% equivalent primary energy)': 1.3533598},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08939'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1971,
#   'Renewables (% equivalent primary energy)': 1.2702763},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0893a'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1972,
#   'Renewables (% equivalent primary energy)': 1.2349532},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0893b'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1973,
#   'Renewables (% equivalent primary energy)': 2.2839267},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0893c'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1974,
#   'Renewables (% equivalent primary energy)': 3.629566},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0893d'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1975,
#   'Renewables (% equivalent primary energy)': 3.8664374},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0893e'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1976,
#   'Renewables (% equivalent primary energy)': 3.5540857},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0893f'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1977,
#   'Renewables (% equivalent primary energy)': 3.9090023},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08940'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1978,
#   'Renewables (% equivalent primary energy)': 5.227204},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08941'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1979,
#   'Renewables (% equivalent primary energy)': 6.702873},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08942'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1980,
#   'Renewables (% equivalent primary energy)': 9.552048},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08943'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1981,
#   'Renewables (% equivalent primary energy)': 9.542367},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08944'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1982,
#   'Renewables (% equivalent primary energy)': 11.229478},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08945'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1983,
#   'Renewables (% equivalent primary energy)': 11.313745},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08946'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1984,
#   'Renewables (% equivalent primary energy)': 12.136334},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08947'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1985,
#   'Renewables (% equivalent primary energy)': 12.759911},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08948'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1986,
#   'Renewables (% equivalent primary energy)': 12.297877},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08949'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1987,
#   'Renewables (% equivalent primary energy)': 12.24687},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0894a'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1988,
#   'Renewables (% equivalent primary energy)': 8.416951},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0894b'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1989,
#   'Renewables (% equivalent primary energy)': 7.543206},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0894c'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1990,
#   'Renewables (% equivalent primary energy)': 10.29241},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0894d'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1991,
#   'Renewables (% equivalent primary energy)': 9.080978},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0894e'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1992,
#   'Renewables (% equivalent primary energy)': 10.2065},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0894f'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1993,
#   'Renewables (% equivalent primary energy)': 12.215968},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08950'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1994,
#   'Renewables (% equivalent primary energy)': 13.306112},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08951'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1995,
#   'Renewables (% equivalent primary energy)': 12.535252},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08952'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1996,
#   'Renewables (% equivalent primary energy)': 10.224623},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08953'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1997,
#   'Renewables (% equivalent primary energy)': 12.513889},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08954'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1998,
#   'Renewables (% equivalent primary energy)': 11.481932},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08955'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1999,
#   'Renewables (% equivalent primary energy)': 9.2246065},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08956'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2000,
#   'Renewables (% equivalent primary energy)': 12.283152},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08957'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2001,
#   'Renewables (% equivalent primary energy)': 15.93624},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08958'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2002,
#   'Renewables (% equivalent primary energy)': 16.247978},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08959'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2003,
#   'Renewables (% equivalent primary energy)': 14.40661},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0895a'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2004,
#   'Renewables (% equivalent primary energy)': 12.185576},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0895b'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2005,
#   'Renewables (% equivalent primary energy)': 12.790038},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0895c'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2006,
#   'Renewables (% equivalent primary energy)': 13.449896},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0895d'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2007,
#   'Renewables (% equivalent primary energy)': 10.613073},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0895e'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2008,
#   'Renewables (% equivalent primary energy)': 10.447249},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0895f'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2009,
#   'Renewables (% equivalent primary energy)': 11.797741},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08960'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2010,
#   'Renewables (% equivalent primary energy)': 11.650168},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08961'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2011,
#   'Renewables (% equivalent primary energy)': 10.914268},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08962'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2012,
#   'Renewables (% equivalent primary energy)': 10.176803},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08963'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2013,
#   'Renewables (% equivalent primary energy)': 10.940409},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08964'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2014,
#   'Renewables (% equivalent primary energy)': 11.038969},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08965'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2015,
#   'Renewables (% equivalent primary energy)': 10.89336},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08966'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2016,
#   'Renewables (% equivalent primary energy)': 10.17179},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08967'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2017,
#   'Renewables (% equivalent primary energy)': 10.979133},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08968'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2018,
#   'Renewables (% equivalent primary energy)': 11.331651},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08969'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2019,
#   'Renewables (% equivalent primary energy)': 11.911147},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0896a'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2020,
#   'Renewables (% equivalent primary energy)': 12.310073},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0896b'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2021,
#   'Renewables (% equivalent primary energy)': 11.335143},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0896c'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2022,
#   'Renewables (% equivalent primary energy)': 12.188763},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0896d'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2023,
#   'Renewables (% equivalent primary energy)': 14.102216},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0896e'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1965,
#   'Renewables (% equivalent primary energy)': 7.8735447},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0896f'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1966,
#   'Renewables (% equivalent primary energy)': 7.4938087},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08970'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1967,
#   'Renewables (% equivalent primary energy)': 6.7346387},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08971'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1968,
#   'Renewables (% equivalent primary energy)': 6.963028},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08972'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1969,
#   'Renewables (% equivalent primary energy)': 6.3012996},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08973'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1970,
#   'Renewables (% equivalent primary energy)': 5.661888},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08974'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1971,
#   'Renewables (% equivalent primary energy)': 5.6825113},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08975'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1972,
#   'Renewables (% equivalent primary energy)': 5.4817533},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08976'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1973,
#   'Renewables (% equivalent primary energy)': 4.7254024},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08977'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1974,
#   'Renewables (% equivalent primary energy)': 5.289435},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08978'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1975,
#   'Renewables (% equivalent primary energy)': 5.432976},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08979'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1976,
#   'Renewables (% equivalent primary energy)': 5.272847},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0897a'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1977,
#   'Renewables (% equivalent primary energy)': 4.885452},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0897b'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1978,
#   'Renewables (% equivalent primary energy)': 4.842396},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0897c'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1979,
#   'Renewables (% equivalent primary energy)': 5.0050187},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0897d'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1980,
#   'Renewables (% equivalent primary energy)': 5.387261},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0897e'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1981,
#   'Renewables (% equivalent primary energy)': 5.6962633},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0897f'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1982,
#   'Renewables (% equivalent primary energy)': 5.688111},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08980'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1983,
#   'Renewables (% equivalent primary energy)': 5.652118},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08981'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1984,
#   'Renewables (% equivalent primary energy)': 5.339281},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08982'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1985,
#   'Renewables (% equivalent primary energy)': 5.351906},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08983'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1986,
#   'Renewables (% equivalent primary energy)': 5.190978},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08984'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1987,
#   'Renewables (% equivalent primary energy)': 5.0590653},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08985'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1988,
#   'Renewables (% equivalent primary energy)': 5.4249687},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08986'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1989,
#   'Renewables (% equivalent primary energy)': 5.319675},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08987'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1990,
#   'Renewables (% equivalent primary energy)': 5.339282},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08988'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1991,
#   'Renewables (% equivalent primary energy)': 5.1891055},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08989'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1992,
#   'Renewables (% equivalent primary energy)': 5.0055637},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0898a'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1993,
#   'Renewables (% equivalent primary energy)': 5.3127103},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0898b'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1994,
#   'Renewables (% equivalent primary energy)': 5.0516157},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0898c'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1995,
#   'Renewables (% equivalent primary energy)': 5.271553},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0898d'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1996,
#   'Renewables (% equivalent primary energy)': 5.018597},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0898e'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1997,
#   'Renewables (% equivalent primary energy)': 4.8939986},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0898f'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1998,
#   'Renewables (% equivalent primary energy)': 5.178817},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08990'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1999,
#   'Renewables (% equivalent primary energy)': 4.9296236},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08991'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2000,
#   'Renewables (% equivalent primary energy)': 4.9015436},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08992'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2001,
#   'Renewables (% equivalent primary energy)': 5.0736527},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08993'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2002,
#   'Renewables (% equivalent primary energy)': 4.9854317},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08994'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2003,
#   'Renewables (% equivalent primary energy)': 4.7931614},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08995'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2004,
#   'Renewables (% equivalent primary energy)': 5.0985446},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08996'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2005,
#   'Renewables (% equivalent primary energy)': 4.9199796},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08997'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2006,
#   'Renewables (% equivalent primary energy)': 5.117429},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08998'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2007,
#   'Renewables (% equivalent primary energy)': 5.0853057},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08999'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2008,
#   'Renewables (% equivalent primary energy)': 5.605236},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0899a'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2009,
#   'Renewables (% equivalent primary energy)': 5.458485},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0899b'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2010,
#   'Renewables (% equivalent primary energy)': 5.9468226},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0899c'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2011,
#   'Renewables (% equivalent primary energy)': 5.8778787},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0899d'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2012,
#   'Renewables (% equivalent primary energy)': 6.4778247},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0899e'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2013,
#   'Renewables (% equivalent primary energy)': 6.987413},
#  {'_id': ObjectId('6808a04ef7b9659dcdf0899f'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2014,
#   'Renewables (% equivalent primary energy)': 7.551866},
#  {'_id': ObjectId('6808a04ef7b9659dcdf089a0'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2015,
#   'Renewables (% equivalent primary energy)': 7.908183},
#  {'_id': ObjectId('6808a04ef7b9659dcdf089a1'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2016,
#   'Renewables (% equivalent primary energy)': 8.438702},
#  {'_id': ObjectId('6808a04ef7b9659dcdf089a2'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2017,
#   'Renewables (% equivalent primary energy)': 8.845372},
#  {'_id': ObjectId('6808a04ef7b9659dcdf089a3'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2018,
#   'Renewables (% equivalent primary energy)': 9.349624},
#  {'_id': ObjectId('6808a04ef7b9659dcdf089a4'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2019,
#   'Renewables (% equivalent primary energy)': 10.002659},
#  {'_id': ObjectId('6808a04ef7b9659dcdf089a5'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2020,
#   'Renewables (% equivalent primary energy)': 10.741154},
#  {'_id': ObjectId('6808a04ef7b9659dcdf089a6'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2021,
#   'Renewables (% equivalent primary energy)': 11.2254095},
#  {'_id': ObjectId('6808a04ef7b9659dcdf089a7'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2022,
#   'Renewables (% equivalent primary energy)': 11.969987},
#  {'_id': ObjectId('6808a04ef7b9659dcdf089a8'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2023,
#   'Renewables (% equivalent primary energy)': 12.191386},
#  {'_id': ObjectId('6808a04ef7b9659dcdf089a9'),
#   'Entity': 'Asia Pacific (EI)',
#   'Code': nan,
#   'Year': 1965,
#   'Renewables (% equivalent primary energy)': 8.879346},
#  {'_id': ObjectId('6808a04ef7b9659dcdf089aa'),
#   'Entity': 'Asia Pacific (EI)',
#   'Code': nan,
#   'Year': 1966,
#   'Renewables (% equivalent primary energy)': 8.41833},
#  {'_id': ObjectId('6808a04ef7b9659dcdf089ab'),
#   'Entity': 'Asia Pacific (EI)',
#   'Code': nan,
#   'Year': 1967,
#   'Renewables (% equivalent primary energy)': 7.6206317},
#  {'_id': ObjectId('6808a04ef7b9659dcdf089ac'),
#   'Entity': 'Asia Pacific (EI)',
#   'Code': nan,
#   'Year': 1968,
#   'Renewables (% equivalent primary energy)': 7.814885},
#  {'_id': ObjectId('6808a04ef7b9659dcdf089ad'),
#   'Entity': 'Asia Pacific (EI)',
#   'Code': nan,
#   'Year': 1969,
# ...
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1976,
#   'Renewables (% equivalent primary energy)': 13.12191},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c0a'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1977,
#   'Renewables (% equivalent primary energy)': 12.341241},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c0b'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1978,
#   'Renewables (% equivalent primary energy)': 15.349611},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c0c'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1979,
#   'Renewables (% equivalent primary energy)': 17.265028},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c0d'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1980,
#   'Renewables (% equivalent primary energy)': 20.214928},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c0e'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1981,
#   'Renewables (% equivalent primary energy)': 22.399574},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c0f'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1982,
#   'Renewables (% equivalent primary energy)': 22.183714},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c10'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1983,
#   'Renewables (% equivalent primary energy)': 23.578016},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c11'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1984,
#   'Renewables (% equivalent primary energy)': 25.592047},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c12'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1985,
#   'Renewables (% equivalent primary energy)': 26.786247},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c13'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1986,
#   'Renewables (% equivalent primary energy)': 29.564842},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c14'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1987,
#   'Renewables (% equivalent primary energy)': 28.886547},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c15'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1988,
#   'Renewables (% equivalent primary energy)': 30.695482},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c16'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1989,
#   'Renewables (% equivalent primary energy)': 31.725052},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c17'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1990,
#   'Renewables (% equivalent primary energy)': 32.043663},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c18'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1991,
#   'Renewables (% equivalent primary energy)': 29.83178},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c19'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1992,
#   'Renewables (% equivalent primary energy)': 27.12252},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c1a'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1993,
#   'Renewables (% equivalent primary energy)': 27.521982},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c1b'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1994,
#   'Renewables (% equivalent primary energy)': 25.153784},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c1c'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1995,
#   'Renewables (% equivalent primary energy)': 23.175493},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c1d'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1996,
#   'Renewables (% equivalent primary energy)': 25.864536},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c1e'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1997,
#   'Renewables (% equivalent primary energy)': 24.05491},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c1f'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1998,
#   'Renewables (% equivalent primary energy)': 21.420517},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c20'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1999,
#   'Renewables (% equivalent primary energy)': 24.960342},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c21'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2000,
#   'Renewables (% equivalent primary energy)': 25.19626},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c22'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2001,
#   'Renewables (% equivalent primary energy)': 22.390955},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c23'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2002,
#   'Renewables (% equivalent primary energy)': 23.148567},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c24'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2003,
#   'Renewables (% equivalent primary energy)': 23.086876},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c25'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2004,
#   'Renewables (% equivalent primary energy)': 23.529451},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c26'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2005,
#   'Renewables (% equivalent primary energy)': 24.86708},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c27'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2006,
#   'Renewables (% equivalent primary energy)': 24.72052},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c28'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2007,
#   'Renewables (% equivalent primary energy)': 24.016212},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c29'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2008,
#   'Renewables (% equivalent primary energy)': 25.384161},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c2a'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2009,
#   'Renewables (% equivalent primary energy)': 25.172054},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c2b'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2010,
#   'Renewables (% equivalent primary energy)': 27.074661},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c2c'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2011,
#   'Renewables (% equivalent primary energy)': 26.338593},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c2d'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2012,
#   'Renewables (% equivalent primary energy)': 27.493683},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c2e'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2013,
#   'Renewables (% equivalent primary energy)': 27.202362},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c2f'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2014,
#   'Renewables (% equivalent primary energy)': 27.154976},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c30'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2015,
#   'Renewables (% equivalent primary energy)': 26.713547},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c31'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2016,
#   'Renewables (% equivalent primary energy)': 26.798523},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c32'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2017,
#   'Renewables (% equivalent primary energy)': 28.610437},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c33'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2018,
#   'Renewables (% equivalent primary energy)': 29.266819},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c34'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2019,
#   'Renewables (% equivalent primary energy)': 25.451958},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c35'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2020,
#   'Renewables (% equivalent primary energy)': 32.487274},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c36'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2021,
#   'Renewables (% equivalent primary energy)': 31.537489},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c37'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2022,
#   'Renewables (% equivalent primary energy)': 30.899012},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c38'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2023,
#   'Renewables (% equivalent primary energy)': 26.829386},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c39'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1965,
#   'Renewables (% equivalent primary energy)': 16.141762},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c3a'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1966,
#   'Renewables (% equivalent primary energy)': 15.867013},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c3b'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1967,
#   'Renewables (% equivalent primary energy)': 15.8887},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c3c'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1968,
#   'Renewables (% equivalent primary energy)': 13.367759},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c3d'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1969,
#   'Renewables (% equivalent primary energy)': 13.999327},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c3e'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1970,
#   'Renewables (% equivalent primary energy)': 14.19122},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c3f'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1971,
#   'Renewables (% equivalent primary energy)': 14.860414},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c40'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1972,
#   'Renewables (% equivalent primary energy)': 17.308092},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c41'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1973,
#   'Renewables (% equivalent primary energy)': 17.450201},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c42'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1974,
#   'Renewables (% equivalent primary energy)': 19.770317},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c43'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1975,
#   'Renewables (% equivalent primary energy)': 21.942268},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c44'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1976,
#   'Renewables (% equivalent primary energy)': 21.900364},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c45'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1977,
#   'Renewables (% equivalent primary energy)': 22.105398},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c46'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1978,
#   'Renewables (% equivalent primary energy)': 22.151817},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c47'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1979,
#   'Renewables (% equivalent primary energy)': 21.552887},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c48'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1980,
#   'Renewables (% equivalent primary energy)': 22.069942},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c49'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1981,
#   'Renewables (% equivalent primary energy)': 22.72726},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c4a'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1982,
#   'Renewables (% equivalent primary energy)': 26.627869},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c4b'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1983,
#   'Renewables (% equivalent primary energy)': 27.825817},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c4c'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1984,
#   'Renewables (% equivalent primary energy)': 27.770302},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c4d'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1985,
#   'Renewables (% equivalent primary energy)': 30.351582},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c4e'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1986,
#   'Renewables (% equivalent primary energy)': 31.423769},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c4f'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1987,
#   'Renewables (% equivalent primary energy)': 32.36392},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c50'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1988,
#   'Renewables (% equivalent primary energy)': 28.551182},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c51'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1989,
#   'Renewables (% equivalent primary energy)': 21.783056},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c52'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1990,
#   'Renewables (% equivalent primary energy)': 18.957916},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c53'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1991,
#   'Renewables (% equivalent primary energy)': 24.08466},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c54'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1992,
#   'Renewables (% equivalent primary energy)': 28.355387},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c55'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1993,
#   'Renewables (% equivalent primary energy)': 27.529266},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c56'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1994,
#   'Renewables (% equivalent primary energy)': 25.954521},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c57'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1995,
#   'Renewables (% equivalent primary energy)': 26.028479},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c58'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1996,
#   'Renewables (% equivalent primary energy)': 22.5519},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c59'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1997,
#   'Renewables (% equivalent primary energy)': 21.909548},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c5a'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1998,
#   'Renewables (% equivalent primary energy)': 18.059258},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c5b'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1999,
#   'Renewables (% equivalent primary energy)': 15.275814},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c5c'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2000,
#   'Renewables (% equivalent primary energy)': 19.783125},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c5d'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2001,
#   'Renewables (% equivalent primary energy)': 22.047363},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c5e'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2002,
#   'Renewables (% equivalent primary energy)': 22.87545},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c5f'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2003,
#   'Renewables (% equivalent primary energy)': 22.010805},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c60'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2004,
#   'Renewables (% equivalent primary energy)': 19.43779},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c61'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2005,
#   'Renewables (% equivalent primary energy)': 22.099463},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c62'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2006,
#   'Renewables (% equivalent primary energy)': 22.957874},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c63'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2007,
#   'Renewables (% equivalent primary energy)': 19.440195},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c64'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2008,
#   'Renewables (% equivalent primary energy)': 21.59478},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c65'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2009,
#   'Renewables (% equivalent primary energy)': 22.96064},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c66'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2010,
#   'Renewables (% equivalent primary energy)': 19.835663},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c67'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2011,
#   'Renewables (% equivalent primary energy)': 18.481121},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c68'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2012,
#   'Renewables (% equivalent primary energy)': 18.747072},
#  {'_id': ObjectId('6808a04ef7b9659dcdf08c69'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2013,
#   'Renewables (% equivalent primary energy)': 18.79665},
#  ...]

# %%
renewable_energy_df = pd.DataFrame(renewable_list_cursor)

# %%
renewable_energy_df
# Out:
#                            _id  Entity      Code  Year  \
# 0     6808a04ef7b9659dcdf08882  Africa       NaN  1965
# 1     6808a04ef7b9659dcdf08883  Africa       NaN  1966
# 2     6808a04ef7b9659dcdf08884  Africa       NaN  1967
# 3     6808a04ef7b9659dcdf08885  Africa       NaN  1968
# 4     6808a04ef7b9659dcdf08886  Africa       NaN  1969
# ...                        ...     ...       ...   ...
# 4898  6808a04ef7b9659dcdf09ba4   World  OWID_WRL  2019
# 4899  6808a04ef7b9659dcdf09ba5   World  OWID_WRL  2020
# 4900  6808a04ef7b9659dcdf09ba6   World  OWID_WRL  2021
# 4901  6808a04ef7b9659dcdf09ba7   World  OWID_WRL  2022
# 4902  6808a04ef7b9659dcdf09ba8   World  OWID_WRL  2023
#
#       Renewables (% equivalent primary energy)
# 0                                     5.740281
# 1                                     6.113969
# 2                                     6.316580
# 3                                     6.994845
# 4                                     7.943916
# ...                                        ...
# 4898                                 12.228147
# 4899                                 13.404395
# 4900                                 13.469198
# 4901                                 14.119935
# 4902                                 14.562141
#
# [4903 rows x 5 columns]

# %%
renewable_energy_df.drop(columns=["Code"], inplace=True, axis=1)

# %%
renewable_energy_df.drop(columns=["_id"], inplace=True, axis=1)

# %%
renewable_energy_df.rename(columns={"Entity": "Area"}, inplace=True)

# %%
renewable_energy_df.rename(columns={'Renewables (% equivalent primary energy)': 'Renewable_Energy_Share'}, inplace=True)

# %%
renewable_energy_df.head()
# Out:
#      Area  Year  Renewable_Energy_Share
# 0  Africa  1965                5.740281
# 1  Africa  1966                6.113969
# 2  Africa  1967                6.316580
# 3  Africa  1968                6.994845
# 4  Africa  1969                7.943916

# %%
pgconn=psycopg2.connect(host="localhost", database="co2_renew_life", user="postgres", password="root")

# %%
pgcursor=pgconn.cursor()

# %%
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT

pgconn.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

# %%
pgcursor.execute("CREATE TABLE IF NOT EXISTS renewable_energy (Area TEXT, Year INT, Renewable_Energy_Share FLOAT);")

# %%
from psycopg2.extras import execute_values

execute_values(pgcursor, "INSERT INTO renewable_energy (Area, Year, Renewable_Energy_Share) VALUES %s", renewable_energy_df.values.tolist())

# %%
pgconn.commit()

# %%
def check_mongodb_collection(client, db_name, collection_name):
    try:
        db = client[db_name]
        print(f"Connected to database: {db_name}")
        collections = db.list_collection_names()
        print(f"Collections in {db_name}: {collections}")
        
        if collection_name not in collections:
            print(f"Collection '{collection_name}' does not exist in {db_name}")
            return False
        
        collection = db[collection_name]
        doc_count = collection.count_documents({})
        print(f"Number of documents in {collection_name}: {doc_count}")
        
        if doc_count == 0:
            print(f"Collection '{collection_name}' is empty")
            return False
        
        sample_doc = collection.find_one()
        print(f"Sample document from {collection_name}: {sample_doc}")
        return True
    except Exception as e:
        print(f"Error accessing {db_name}/{collection_name}: {e}")
        return False


print("--- Processing Carbon Emissions Data ---")

try:
    client = pymongo.MongoClient("mongodb://localhost:27017/")
    print("MongoDB connection successful")
    print("Available databases:", client.list_database_names())
except Exception as e:
    print(f"Failed to connect to MongoDB: {e}")
    client = None

if client:
    if check_mongodb_collection(client, "co2_renew_life_db", "carbon_emissions"):
        db = client["co2_renew_life_db"]
        emissions_collection = db["carbon_emissions"]

        emissions_all_records = emissions_collection.find()
        emissions_list_cursor = list(emissions_all_records)
        print(f"Retrieved {len(emissions_list_cursor)} records from carbon_emissions")

        emissions_df = pd.DataFrame(emissions_list_cursor)

        if emissions_df.empty:
            print("Emissions DataFrame is empty")
        else:
            print("Emissions DataFrame shape:", emissions_df.shape)
            print("Emissions DataFrame columns:", emissions_df.columns)
            print("Emissions DataFrame missing values:\n", emissions_df.isnull().sum())
            print("Emissions DataFrame head:\n", emissions_df.head())

            if '_id' in emissions_df.columns:
                emissions_df.drop(columns=["_id"], inplace=True)
            if 'Code' in emissions_df.columns:
                emissions_df.drop(columns=["Code"], inplace=True)

            emissions_df.rename(columns={
                "Entity": "Area",
                "Year": "Year",
                "Annual CO₂ emissions (per capita)": "CO2_Emissions_Per_Capita"
            }, inplace=True)

            print("Cleaned Emissions DataFrame head:\n", emissions_df.head())
    else:
        print("Skipping emissions data processing due to empty or missing collection")
else:
    print("Skipping emissions data processing due to connection failure")
# Out:
# --- Processing Carbon Emissions Data ---
# MongoDB connection successful
# Available databases: ['admin', 'co2_renew_life_db', 'config', 'life_expectancy_db', 'local']
# Connected to database: co2_renew_life_db
# Collections in co2_renew_life_db: ['carbon_emissions', 'life_expectancy', 'renewable_energy']
# Number of documents in carbon_emissions: 26182
# Sample document from carbon_emissions: {'_id': ObjectId('6808a04ef7b9659dcdf0223c'), 'Entity': 'Afghanistan', 'Code': 'AFG', 'Year': 1949, 'Annual CO₂ emissions (per capita)': 0.0019921463}
# Retrieved 26182 records from carbon_emissions
# Emissions DataFrame shape: (26182, 5)
# Emissions DataFrame columns: Index(['_id', 'Entity', 'Code', 'Year', 'Annual CO₂ emissions (per capita)'], dtype='object')
# Emissions DataFrame missing values:
#  _id                                     0
# Entity                                  0
# Code                                 3287
# Year                                    0
# Annual CO₂ emissions (per capita)       0
# dtype: int64
# Emissions DataFrame head:
#                          _id       Entity Code  Year  \
# 0  6808a04ef7b9659dcdf0223c  Afghanistan  AFG  1949
# 1  6808a04ef7b9659dcdf0223d  Afghanistan  AFG  1950
# 2  6808a04ef7b9659dcdf0223e  Afghanistan  AFG  1951
# 3  6808a04ef7b9659dcdf0223f  Afghanistan  AFG  1952
# 4  6808a04ef7b9659dcdf02240  Afghanistan  AFG  1953
#
#    Annual CO₂ emissions (per capita)
# 0                           0.001992
# 1                           0.010837
# 2                           0.011625
# 3                           0.011468
# 4                           0.013123
# Cleaned Emissions DataFrame head:
#            Area  Year  CO2_Emissions_Per_Capita
# 0  Afghanistan  1949                  0.001992
# 1  Afghanistan  1950                  0.010837
# 2  Afghanistan  1951                  0.011625
# 3  Afghanistan  1952                  0.011468
# 4  Afghanistan  1953                  0.013123

# %%
emissions_df.head()
# Out:
#           Area  Year  CO2_Emissions_Per_Capita
# 0  Afghanistan  1949                  0.001992
# 1  Afghanistan  1950                  0.010837
# 2  Afghanistan  1951                  0.011625
# 3  Afghanistan  1952                  0.011468
# 4  Afghanistan  1953                  0.013123

# %%
pgconn=psycopg2.connect(host="localhost", database="co2_renew_life", user="postgres", password="root")

# %%
pgcursor=pgconn.cursor()

# %%
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT

pgconn.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

# %%
pgcursor.execute("CREATE TABLE IF NOT EXISTS carbon_emissions (Area TEXT, Year INT, CO2_Emissions_Per_Capita FLOAT);")

# %%
from psycopg2.extras import execute_values

execute_values(pgcursor, "INSERT INTO carbon_emissions (Area, Year, CO2_Emissions_Per_Capita) VALUES %s", emissions_df.values.tolist())

# %%
pgconn.commit()

# %%
if client:
    if check_mongodb_collection(client, "co2_renew_life_db", "life_expectancy"):
        db = client["co2_renew_life_db"]
        life_expectancy_collection = db["life_expectancy"]

        life_expectancy_all_records = life_expectancy_collection.find()
        life_expectancy_list_cursor = list(life_expectancy_all_records)
        print(f"Retrieved {len(life_expectancy_list_cursor)} records from life_expectancy")

        life_expectancy_df = pd.DataFrame(life_expectancy_list_cursor)

        if life_expectancy_df.empty:
            print("Life Expectancy DataFrame is empty")
        else:
            print("Life Expectancy DataFrame shape:", life_expectancy_df.shape)
            print("Life Expectancy DataFrame columns:", life_expectancy_df.columns)
            print("Life Expectancy DataFrame missing values:\n", life_expectancy_df.isnull().sum())
            print("Life Expectancy DataFrame head:\n", life_expectancy_df.head())

            if '_id' in life_expectancy_df.columns:
                life_expectancy_df.drop(columns=["_id"], inplace=True)
            if 'Code' in life_expectancy_df.columns:
                life_expectancy_df.drop(columns=["Code"], inplace=True)

            life_expectancy_df.rename(columns={
                "Entity": "Area",
                "Year": "Year",
                "Period life expectancy at birth - Sex: total - Age: 0": "Life_Expectancy"
            }, inplace=True)

            print("Cleaned Life Expectancy DataFrame head:\n", life_expectancy_df.head())
    else:
        print("Skipping life expectancy data processing due to empty or missing collection")
else:
    print("Skipping life expectancy data processing due to connection failure")
# Out:
# Connected to database: co2_renew_life_db
# Collections in co2_renew_life_db: ['carbon_emissions', 'life_expectancy', 'renewable_energy']
# Number of documents in life_expectancy: 21565
# Sample document from life_expectancy: {'_id': ObjectId('6808a04ff7b9659dcdf09ba9'), 'Entity': 'Afghanistan', 'Code': 'AFG', 'Year': 1950, 'Period life expectancy at birth - Sex: total - Age: 0': 28.1563}
# Retrieved 21565 records from life_expectancy
# Life Expectancy DataFrame shape: (21565, 5)
# Life Expectancy DataFrame columns: Index(['_id', 'Entity', 'Code', 'Year',
#        'Period life expectancy at birth - Sex: total - Age: 0'],
#       dtype='object')
# Life Expectancy DataFrame missing values:
#  _id                                                         0
# Entity                                                      0
# Code                                                     1956
# Year                                                        0
# Period life expectancy at birth - Sex: total - Age: 0       0
# dtype: int64
# Life Expectancy DataFrame head:
#                          _id       Entity Code  Year  \
# 0  6808a04ff7b9659dcdf09ba9  Afghanistan  AFG  1950
# 1  6808a04ff7b9659dcdf09baa  Afghanistan  AFG  1951
# 2  6808a04ff7b9659dcdf09bab  Afghanistan  AFG  1952
# 3  6808a04ff7b9659dcdf09bac  Afghanistan  AFG  1953
# 4  6808a04ff7b9659dcdf09bad  Afghanistan  AFG  1954
#
#    Period life expectancy at birth - Sex: total - Age: 0
# 0                                            28.1563
# 1                                            28.5836
# 2                                            29.0138
# 3                                            29.4521
# 4                                            29.6975
# Cleaned Life Expectancy DataFrame head:
#            Area  Year  Life_Expectancy
# 0  Afghanistan  1950          28.1563
# 1  Afghanistan  1951          28.5836
# 2  Afghanistan  1952          29.0138
# 3  Afghanistan  1953          29.4521
# 4  Afghanistan  1954          29.6975

# %%
life_expectancy_df.head()
# Out:
#           Area  Year  Life_Expectancy
# 0  Afghanistan  1950          28.1563
# 1  Afghanistan  1951          28.5836
# 2  Afghanistan  1952          29.0138
# 3  Afghanistan  1953          29.4521
# 4  Afghanistan  1954          29.6975

# %%
pgconn=psycopg2.connect(host="localhost", database="co2_renew_life", user="postgres", password="root")

# %%
pgcursor=pgconn.cursor()

# %%
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT

pgconn.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

# %%
pgcursor.execute("CREATE TABLE IF NOT EXISTS life_expectancy (Area TEXT, Year INT, Life_Expectancy FLOAT);")

# %%
from psycopg2.extras import execute_values

execute_values(pgcursor, "INSERT INTO life_expectancy (Area, Year, Life_Expectancy) VALUES %s", life_expectancy_df.values.tolist())

# %%
pgconn.commit()
